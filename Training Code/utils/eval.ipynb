# %%
import numpy as np
import pickle 

from sklearn.metrics import balanced_accuracy_score,accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns
from sklearn import metrics
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_fscore_support
# %matplotlib inline

# %%
pickle_dire='../Result/smarthome/skeleton/alphapose/CD3/LSTM/'

# %%
with open(pickle_dire+'/res.pickle','rb') as f:
    res=pickle.load(f)

y_true=res['y_true']
y_pred=res['y_pred']

# %%
classnames=['Drink.Frombottle',
 'Drink.Fromcan',
 'Drink.Fromcup',
 ]

# %%
con_mat=confusion_matrix(y_true,y_pred)

# %%
import sklearn

# %%
sklearn.metrics.accuracy_score(y_true,y_pred)
# Out:
# 0.3936651583710407

# %%
precision_recall_fscore_support(y_true,y_pred,average='weighted')
# Out:
# (0.4038262531941642, 0.3936651583710407, 0.38979463019553806, None)
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Pose

# %%
plt.figure(figsize=(10,10))

sns.heatmap(con_mat,annot=True,xticklabels=classnames,yticklabels=classnames,cbar=False,cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))

sns.heatmap(con_mat,annot=True,xticklabels=classnames,yticklabels=classnames,cbar=False,cmap='coolwarm')
# Out:
# <AxesSubplot: >
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history['pose_accuracy'])
plt.plot(history['val_pose_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.plot(history['rgb_accuracy'])
plt.plot(history['val_rgb_accuracy'])

plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Out:
# dict_keys(['loss', 'pose_loss', 'rgb_loss', 'pose_accuracy', 'rgb_accuracy', 'val_loss', 'val_pose_loss', 'val_rgb_loss', 'val_pose_accuracy', 'val_rgb_accuracy'])

# %%
# Plot training & validation loss values
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
history['val_accuracy']
# Out:
# [0.33766233921051025,
#  0.37662336230278015,
#  0.3636363744735718,
#  0.3246753215789795,
#  0.38528138399124146,
#  0.3419913351535797,
#  0.3549783527851105,
#  0.4025973975658417,
#  0.3722943663597107,
#  0.4025973975658417,
#  0.41558441519737244,
#  0.4588744640350342,
#  0.4588744640350342,
#  0.42424243688583374,
#  0.4458874464035034,
#  0.47186148166656494,
#  0.4372294247150421,
#  0.46320345997810364,
#  0.5324675440788269,
#  0.4935064911842346,
#  0.5021644830703735,
#  0.5108225345611572,
#  0.5151515007019043,
#  0.4761904776096344,
#  0.47186148166656494,
#  0.5324675440788269,
#  0.5021644830703735,
#  0.4935064911842346,
#  0.4978354871273041,
#  0.4675324559211731,
#  0.47186148166656494,
#  0.5541125535964966,
#  0.5584415793418884,
#  0.5627705454826355,
#  0.5281385183334351,
#  0.5844155550003052,
#  0.5541125535964966,
#  0.5714285969734192,
#  0.5541125535964966,
#  0.5541125535964966,
#  0.5454545617103577,
#  0.5021644830703735,
#  0.5411255359649658,
# ...
